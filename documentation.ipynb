# %% [markdown]
# lean production-style banking system skeleton in:
#
# ☕ Java (Spring-style layered thinking, but plain core first)
#
# 🐍 Python (FastAPI-style layered thinking, but plain core first)

# %% [markdown]
# Enterprise Digital Banking System (Core Skeleton)
#
# Phase 1
#
# Build layered architecture:
#
# ![image.png](attachment:image.png)
#
# This prepares us for:
# - Repository Pattern
# - Dependency Injection
# - SOLID
# - MVC

# %% [markdown]
# 1 — Domain Models
#
# We start with core entities:
# - User
# - Account
# - Transaction
# - AccountType
# - AccountStatus

# %% [markdown]
# 2 — Repository Layer
#
# We simulate database using in-memory storage.
#
# This prepares us for:
# - Repository Pattern
# - Dependency Injection

# %% [markdown]
# 3 — Service Layer
#
# Business logic lives here.

# %% [markdown]
# 4 — Entry Point

# %% [markdown]
# What We Just Built
#
# We now have:
# - Domain model
# - Repository layer
# - Service layer
# - Basic separation of concerns
#
# This is already production-style architecture.

# %% [markdown]
# Right now we are NOT using:
# - Factory
# - Strategy
# - Observer
# - State
# - DI framework
# - etc.
#
# We built the naive version.

# %% [markdown]
# Now complexity will increase.
#
# We’ll add:
# - Multiple account types with different interest logic
# - Loan approval workflow
# - Transaction events
# - Notification system
#
# Then patterns will naturally appear.

# %% [markdown]
# Date: 12th February, 2026
#
# #### what we get
#
# Before:
# - Service directly created Account
# - Hard to extend
# - Violates Open/Closed Principle
#
# After:
# - Service depends on abstraction
# - New account types can be added without modifying service
# - Cleaner architecture

# %% [markdown]
# Real Production Benefit
#
# If tomorrow bank introduces:
# - StudentAccount
# - NRIAccount
# - CryptoAccount
#
# You just add new class.
#
# No service modification.
#
# That’s real engineering.

# %% [markdown]
# now we will face:
#
# Interest calculation may vary by:
# - Region
# - Account tier
# - Promotional period
#
# Instead of hardcoding inside account,
#
# we will use:
# - Strategy Pattern OR
#
# We can improve this factory into:
# - Abstract Factory (for region-based banking systems)
